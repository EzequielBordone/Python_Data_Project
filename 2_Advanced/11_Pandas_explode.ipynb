# %% [markdown]
# # Pandas - explode()

# %%
# import libraries
import ast
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# loading data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# cleanng data
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# cleaning the 'job_skills' into a list datatype
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
df[['job_title_short', 'job_skills']].head(5)
# Out:
#         job_title_short                                         job_skills
# 0  Senior Data Engineer                                               None
# 1          Data Analyst         [r, python, sql, nosql, power bi, tableau]
# 2         Data Engineer  [python, sql, c#, azure, airflow, dax, docker,...
# 3         Data Engineer  [python, c++, java, matlab, aws, tensorflow, k...
# 4         Data Engineer  [bash, python, oracle, aws, ansible, puppet, j...

# %% [markdown]
# let's run the .explode() method on the 'job_skills' columns

# %%
help(df.explode)
# Out:
# Help on method explode in module pandas.core.frame:
#
# explode(column: 'IndexLabel', ignore_index: 'bool' = False) -> 'DataFrame' method of pandas.core.frame.DataFrame instance
#     Transform each element of a list-like to a row, replicating index values.
#
#     Parameters
#     ----------
#     column : IndexLabel
#         Column(s) to explode.
#         For multiple columns, specify a non-empty list with each element
#         be str or tuple, and all specified columns their list-like data
#         on same row of the frame must have matching length.
#
#         .. versionadded:: 1.3.0
#             Multi-column explode
#
#     ignore_index : bool, default False
#         If True, the resulting index will be labeled 0, 1, …, n - 1.
#
#     Returns
#     -------
#     DataFrame
#         Exploded lists to rows of the subset columns;
#         index will be duplicated for these rows.
#
#     Raises
#     ------
#     ValueError :
# ...

# %%
df.explode('job_skills')
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 1               Data Analyst
# 1               Data Analyst
# 1               Data Analyst
# ...                      ...
# 785739         Data Engineer
# 785739         Data Engineer
# 785739         Data Engineer
# 785740     Software Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 1                                            Data Analyst
# 1                                            Data Analyst
# 1                                            Data Analyst
# ...                                                   ...
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# ...

# %%
df_exploded = df.explode('job_skills')

df_exploded
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 1               Data Analyst
# 1               Data Analyst
# 1               Data Analyst
# ...                      ...
# 785739         Data Engineer
# 785739         Data Engineer
# 785739         Data Engineer
# 785740     Software Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 1                                            Data Analyst
# 1                                            Data Analyst
# 1                                            Data Analyst
# ...                                                   ...
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# ...

# %%
""" df_exploded['job_skills'].value_counts().head(10).plot(kind='bar') """
# Out:
# " df_exploded['job_skills'].value_counts().head(10).plot(kind='bar') "

# %%
""" df_exploded = df.explode('job_skills') """
# Out:
# " df_exploded = df.explode('job_skills') "

# %%
""" df_exploded.groupby(['job_title_short', 'job_skills']).size() """
# Out:
# " df_exploded.groupby(['job_title_short', 'job_skills']).size() "

# %%
skills_count = df_exploded.groupby(['job_title_short', 'job_skills']).size()

type(skills_count)
# Out:
# pandas.core.series.Series

# %%
df_skills_count = skills_count.reset_index(name='skill_count')

df_skills_count
# Out:
#         job_title_short job_skills  skill_count
# 0      Business Analyst    airflow          318
# 1      Business Analyst   airtable           17
# 2      Business Analyst    alteryx         1078
# 3      Business Analyst    angular           87
# 4      Business Analyst    ansible          120
# ...                 ...        ...          ...
# 2251  Software Engineer      wrike            4
# 2252  Software Engineer        wsl           13
# 2253  Software Engineer    xamarin           35
# 2254  Software Engineer       yarn          145
# 2255  Software Engineer       zoom          229
#
# [2256 rows x 3 columns]

# %%
""" df_skills_count = skills_count.reset_index(name='skill_count')

df_skills_count = df_skills_count.sort_values(by='skill_count', ascending=False)

df_skills_count """
# Out:
# " df_skills_count = skills_count.reset_index(name='skill_count')\n\ndf_skills_count = df_skills_count.sort_values(by='skill_count', ascending=False)\n\ndf_skills_count "

# %%
""" job_title = 'Data Analyst'
top_skills = 10

df_skills_count = df_skills_count[df_skills_count['job_title_short'] == job_title].head(top_skills)

df_skills_count """
# Out:
# " job_title = 'Data Analyst'\ntop_skills = 10\n\ndf_skills_count = df_skills_count[df_skills_count['job_title_short'] == job_title].head(top_skills)\n\ndf_skills_count "

# %%
""" df_skills_count.plot(kind='barh', x='job_skills', y='skill_count') """
# Out:
# " df_skills_count.plot(kind='barh', x='job_skills', y='skill_count') "

# %%
""" df_skills_count.plot(kind='barh', x='job_skills', y='skill_count')
plt.gca().invert_yaxis() """
# Out:
# " df_skills_count.plot(kind='barh', x='job_skills', y='skill_count')\nplt.gca().invert_yaxis() "

# %%
job_title = 'Data Analyst'
top_skills = 10

df_skills_count = df_skills_count[df_skills_count['job_title_short'] == job_title].head(top_skills)

df_skills_count.plot(kind='barh', x='job_skills', y='skill_count')
plt.gca().invert_yaxis()
plt.title(f'Top {top_skills} Skills for {job_title}s')
plt.xlabel('Job Posting Count')
plt.ylabel('')
plt.legend().set_visible(False)
plt.show
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[144], line 6
#       2 top_skills = 10
#       4 df_skills_count = df_skills_count[df_skills_count['job_title_short'] == job_title].head(top_skills)
# ----> 6 df_skills_count.plot(kind='barh', x='job_skills', y='skill_count')
#       7 plt.gca().invert_yaxis()
#       8 plt.title(f'Top {top_skills} Skills for {job_title}s')
#
# File c:\Users\ezequ\anaconda3\envs\luke_b\Lib\site-packages\pandas\plotting\_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File c:\Users\ezequ\anaconda3\envs\luke_b\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
# ...

# %%
df_skills_count.empty
# Out:
# True
